# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import os
import hcp_utils as hcp
import pandas as pd
import scipy as sp
from itertools import combinations
import ciftools_af as ct
from random import shuffle


def eq_dist(seeds, surface, labels, hemi):
    ### Calculate the level of "equidistance" from 2 or more parcels
    # seeds: list of labels to use as seeds (must match the provided atlas)
    # coordinates: x,y,z coordinates of surface vertices
    # triangles: list of triplets of vertices delimiting each triangle/face of the surface
    # labels: path to labels (cifti2.dlabel.nii)
    # hemi: 'L' or 'R'
    structure = ('CIFTI_STRUCTURE_CORTEX_LEFT' if hemi=='L' else 'CIFTI_STRUCTURE_CORTEX_RIGHT')
    cortex_vtx = struct_to_vtx(structure, labels)
    vertices = surface.darrays[0].data
    triangles = surface.darrays[1].data

    # calculate distance maps from each seed region
    dist_all = []
    for src_tmp in seeds:
        dist = []
        mask, src_vtx = label_to_vtx(src_tmp, labels, structure)
        for vtx_tmp in src_vtx: 
            dist_tmp = gdist.compute_gdist(surf_geo, cortex_vtx[0], src_vtx)
            gd.compute_gdist(vertices, triangles, source_indices=junct_vtx, target_indices=peak_vtx)
            #dist_tmp = sp.stats.zscore(dist_tmp)
#             dists.append(dist_tmp)
            dist += dist_tmp
        dist = dist/len(src_vtx)
        dist_all.append(dist)
        
    # calculate the 'equidistance' measure
    pairs = list(combinations(np.arange(len(seeds)),2))
    equidistance_map = np.zeros(len(surf_geo[0]))
    for idx0, idx1 in pairs:
        eq_tmp = np.abs(dists[idx0]-dists[idx1])
        equidistance_map += eq_tmp
    del surface
    return equidistance_map
# Out:
# /home/fralberti/.local/lib/python3.8/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
### VARIABLES TO SET BEFORE RUNNING
# directory containing subdirectories named fter subject IDs that contain the timeseries and surface files
root_dir = "/home/fralberti/Data/HCP/"
# directory where all intermediate files and the final output will be saved
output_dir = "/home/fralberti/Data/Output_misc/"
# list of IDs of subjects to include in the analyses
f = open(f'{root_dir}subj_IDs_200.txt', 'r')
subj_id = np.array(f.read().splitlines())
del f

# %%
### DISTANCE FROM PRIMARY REGIONS
for subj in subj_id[0:1]:
    geodist = []
    dlabel = nib.load(f'{root_dir}{subj}/Structural/{subj}.aparc.a2009s.32k_fs_LR.dlabel.nii')
    
    #calculate distance from primary regions
    for hemi in ['L','R']:
        source_labels = [f'{hemi}_S_calcarine', f'{hemi}_S_central', f'{hemi}_S_temporal_transverse']
        surface = nib.load(f'{root_dir}{subj}/Structural/{subj}.{hemi}.midthickness_MSMAll.32k_fs_LR.surf.gii')
        i = ct.gdist_label(source_labels, dlabel, surface, hemi, mean=False)
        geodist.append(i)
    prim_gdist = np.hstack([geodist[0],geodist[1]])
    
    # calculate equidistance metric
    eq_gdist = np.zeros([1,prim_gdist.shape[1]])
    pairs = list(combinations(np.arange(3),2))
    for idx0, idx1 in pairs:
        eq_tmp = np.abs(prim_gdist[idx0]-prim_gdist[idx1])
        eq_gdist += eq_tmp
    eq_gdist = (eq_gdist - eq_gdist.min()) / (eq_gdist.max() - eq_gdist.min()) # min-max normalization
    eq_gdist = 1 - eq_gdist # inversion
    
    # caluculate maximal distance
    max_gdist = prim_gdist.prod(axis=0, keepdims=True)
    max_gdist = (max_gdist - max_gdist.min()) / (max_gdist.max() - max_gdist.min()) # min-max normalization
    
    scalars = np.vstack([eq_gdist, max_gdist, prim_gdist])
    output_path = f'{root_dir}{subj}/Structural/{subj}.gdist_prim.32k_fs_LR.dscalar.nii'
    ct.save_dscalar(scalars, dlabel, output_path, names=['eq_gdist','max_gdist', 'S_calcarine', 'S_central', 'S_temporal_transverse'])
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
grad_zone_2 = {}
eq_zone_2 = {}
spearman_df = pd.DataFrame([],columns=['ID','rho','pval'])
for subj in subj_id:
    zones = nib.load(f'{root_dir}/HCP_S1200_GroupAvg_v1/zones.watershed.dlabel.nii')
    offset_L, count_L, _ = ct.struct_info('CIFTI_STRUCTURE_CORTEX_LEFT', zones)
    offset_R, count_R, _ = ct.struct_info('CIFTI_STRUCTURE_CORTEX_RIGHT', zones)
    cortex_zones = zones.get_fdata()[20, np.r_[offset_L : offset_L+count_L, offset_R : offset_R+count_R]]
    grad = nib.load(f'{root_dir}{subj}/{subj}.gcca_200.32k_fs_LR.dscalar.nii').get_fdata()[0, np.r_[offset_L : offset_L+count_L, offset_R : offset_R+count_R]]
    eq_gdist = nib.load(f'{root_dir}{subj}/Structural/{subj}.gdist_prim.32k_fs_LR.dscalar.nii').get_fdata()[0, np.r_[offset_L : offset_L+count_L, offset_R : offset_R+count_R]]
    zone_2 = np.isin(cortex_zones,[2,3])
    
    rho, pval = sp.stats.spearmanr(grad[zone_2], eq_gdist[zone_2], alternative='greater')
    spearman_df = pd.concat([spearman_df,pd.DataFrame([[subj, rho, pval]], columns=['ID','rho','pval'])])
    grad_zone_2[subj] = grad[zone_2]
    eq_zone_2[subj] = eq_gdist[zone_2]
    
    
    
    
spearman_df.reset_index(drop=True).to_csv(f'{output_dir}gradient_distance_r.csv', index=False)
spearman_df
# Out:
#         ID       rho pval
# 0   100206  0.506806  0.0
# 0   100307  0.442568  0.0
# 0   100408  0.473422  0.0
# 0   101006  0.344864  0.0
# 0   101107  0.463903  0.0
# ..     ...       ...  ...
# 0   189652  0.526538  0.0
# 0   190031  0.488935  0.0
# 0   191033  0.444723  0.0
# 0   191235   0.44293  0.0
# 0   191336  0.408351  0.0
#
# [200 rows x 3 columns]

# %%
# concatenated group-level correlation test

iter_n = 10000

grad = []
for g in subj_id:
    grad.extend(grad_zone_2[g].tolist())  
eq = []
for g in subj_id:
    eq.extend(eq_zone_2[g].tolist())
rho_real, _ = sp.stats.spearmanr(grad, eq, alternative='greater')
print(rho_real)

rho_null = []
for i in range(iter_n):
    shuffle_id = np.copy(subj_id)
    while any(shuffle_id==subj_id):
        shuffle(shuffle_id)
    grad = []
    for g in subj_id:
        grad.extend(grad_zone_2[g].tolist())  
    eq = []
    for g in shuffle_id:
        eq.extend(eq_zone_2[g].tolist())    
    rho, _ = sp.stats.spearmanr(grad, eq, alternative='greater')
    rho_null.append(rho)
    
import seaborn as sns
ax = sns.kdeplot(rho_null)
ax.set_xlabel("Sperman's r (null)")

print(f'r = {rho_real} \tp-value =', (100-sp.stats.percentileofscore(rho_null, rho_real))/100)
# Out:
# 0.4576739530583763

# %%
# AUC test
# spearman_df = pd.read_csv(f'{output_dir}gradient_distance_r.csv')
# auc_real = sp.integrate.trapezoid(spearman_df.rho)

# iter_n = 1000
# auc_null = []
# for i in range(iter_n):
#     shuffle_id = np.copy(subj_id)
#     while any(shuffle_id==subj_id):
#         shuffle(shuffle_id)
#     rho_null = []
#     for s,subj in enumerate(subj_id):
#         if subj == shuffle_id[s]:
#             print('!')
#         rho, _ = sp.stats.spearmanr(grad_zone_2[subj], eq_zone_2[shuffle_id[s]], alternative='greater')
#         rho_null.append(rho)
#     auc = sp.integrate.trapezoid(rho_null)
#     auc_null.append(auc)

import seaborn as sns
sns.kdeplot(auc_null, shade=True)
print(f'AUC = {auc_real} \tp-value =', (100-sp.stats.percentileofscore(auc_null, auc_real))/100)
# Out:
# AUC = 87.77684213862275 	p-value = 0.16700000000000004
